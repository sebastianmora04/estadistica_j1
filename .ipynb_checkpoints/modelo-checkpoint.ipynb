# %% [markdown]
# # Análisis del uso de las aulas virtuales UIS
#
# ## Estadística
# ### Unidad I: Estadística descriptiva
# **Prof. Eliana Bonalde**
#
# ___
#
# Algunos métodos para la manipulación y análisis del conjunto de datos de las aulas virtuales.
#
# Importamos las librerías a utilizar y el archivo en formato .CSV

# %%
import pandas as pd
import numpy as np
import statistics as stat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("datos_es.csv")

# %%
#tamaño del archivo
df.shape
# Out:
# (55, 13)

# %%
df = df.drop(['Marca temporal'], axis=1)

# %%
df.head()
# Out:
#                   Carrera  Nivel  \
# 0  INGENIERIA DE SISTEMAS      8
# 1        INGENIERIA CIVIL      5
# 2    INGENIERIA ELECTRICA      9
# 3  INGENIERIA DE SISTEMAS      8
# 4                ECONOMIA      8
#
#   Diariamente, ¿Cuánto tiempo da uso al MOODLE?  \
# 0                                     1-2 horas
# 1                                     3-4 horas
# 2                                     1-2 horas
# 3                                     1-2 horas
# 4                                     1-2 horas
#
#    De 1 a 5, (siendo 1 el menor y 5 el mayor), ¿Con qué frecuencia realiza pruebas en el MOODLE?  \
# 0                                                  2
# 1                                                  3
# 2                                                  2
# 3                                                  2
# 4                                                  4
#
#    De 1 a 10, (siendo 1 el menor y 10 el mayor), ¿Con qué frecuencia realiza trabajos, talleres o tareas en el MOODLE?  \
# 0                                                  2
# 1                                                  6
# 2                                                  4
# 3                                                  2
# 4                                                  7
#
#   ¿Qué uso le ha dado al MOODLE?  \
# 0             Presentar examenes
# 1           Todas las anteriores
# 2           Todas las anteriores
# 3           Todas las anteriores
# 4           Todas las anteriores
#
#   ¿En qué área cree que el aula virtual le ha sido de más utilidad?  \
# 0      Materias de carrera ( arriba de 5to semestre)
# 1      Materias de carrera ( arriba de 5to semestre)
# 2      Materias de carrera ( arriba de 5to semestre)
# 3        Materias de ciencias básicas (ciclo básico)
# 4      Materias de carrera ( arriba de 5to semestre)
#
#    Del 1 al 10, (siendo 1 el menor y 10 el mayor), ¿Qué tan practico y útil le resultan ser las aulas virtuales?  \
# 0                                                  8
# 1                                                  8
# 2                                                  6
# 3                                                  8
# 4                                                  6
#
#   ¿Cuál es la actividad que realiza con más frecuencia en la plataforma MOODLE?  \
# 0                                             Tareas
# 1                                           Talleres
# 2                                      Cuestionarios
# 3                                      Cuestionarios
# 4                                             Tareas
#
#   ¿Con qué frecuencia utiliza los mensajes de la plataforma MOODLE?  \
# 0                                              Nunca
# 1                                               Poco
# 2                                               Poco
# 3                                               Poco
# 4                                              Nunca
#
#   Si su anterior respuesta fue nunca o poco, ¿Qué servicio de mensajes utiliza para comunicarse con sus profesores?  \
# 0                                      Gmail/Hotmail
# 1                               Correo institucional
# 2                                      Gmail/Hotmail
# 3                                              Slack
# 4                                           Whatsapp
#
#   En su opinión, el calendario que se muestra en la plataforma:  \
# 0                        No le prestó casi atención.
# 1                                      Puede mejorar
# 2                   Está completo, bien implementado
# 3                                    No me he fijado
# 4                                      Puede mejorar
#
#   ¿Hace uso de otra plataforma educativa dentro de la universidad? ¿Cuál?
# 0                        La plataforma de las notas.
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# Renombramos las columnas

# %%
df.columns = ['Carrera', 'Nivel', 'Tiempo de uso', 'Frecuencia pruebas', 'Frecuencia talleres',
              'Uso a moodle', 'Area mayor utilidad', 'Practicidad', 'Actividad mayor frecuencia', 
              'Mensajeria', 'Otro serivicio mensajes', 'Calendario','Otra plataforma usada'] 
df.head(1) #muestra solo la primera fila
# Out:
#                   Carrera  Nivel Tiempo de uso  Frecuencia pruebas  \
# 0  INGENIERIA DE SISTEMAS      8     1-2 horas                   2
#
#    Frecuencia talleres        Uso a moodle  \
# 0                    2  Presentar examenes
#
#                              Area mayor utilidad  Practicidad  \
# 0  Materias de carrera ( arriba de 5to semestre)            8
#
#   Actividad mayor frecuencia Mensajeria Otro serivicio mensajes  \
# 0                     Tareas      Nunca           Gmail/Hotmail
#
#                     Calendario        Otra plataforma usada
# 0  No le prestó casi atención.  La plataforma de las notas.

# %% [markdown]
# Pedimos información sobre los datos (filas y columnas)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Carrera                     55 non-null     object
#  1   Nivel                       55 non-null     int64
#  2   Tiempo de uso               55 non-null     object
#  3   Frecuencia pruebas          55 non-null     int64
#  4   Frecuencia talleres         55 non-null     int64
#  5   Uso a moodle                55 non-null     object
#  6   Area mayor utilidad         55 non-null     object
#  7   Practicidad                 55 non-null     int64
#  8   Actividad mayor frecuencia  55 non-null     object
#  9   Mensajeria                  55 non-null     object
#  10  Otro serivicio mensajes     54 non-null     object
#  11  Calendario                  55 non-null     object
#  12  Otra plataforma usada       24 non-null     object
# dtypes: int64(4), object(9)
# memory usage: 5.7+ KB

# %% [markdown]
# No hay datos nulos, en caso de haberlo podríamos utilizar la siguiente celda para eliminar las filas que los contengan (está comentada).

# %%
#eliminar las filas que contengan datos nulos
#df = df.dropna(axis=0)

# %% [markdown]
# Pedimos los valores filas por columnas.

# %%
df['Carrera'].unique()
# Out:
# array(['INGENIERIA DE SISTEMAS', 'INGENIERIA CIVIL',
#        'INGENIERIA ELECTRICA', 'ECONOMIA', 'TRABAJO SOCIAL', 'BIOLOGIA',
#        'DERECHO', 'INGENIERIA ELECTRONICA', 'QUIMICA', 'GEOLOGIA',
#        'FILOSOFIA', 'DISEÑO INDUSTRIAL', 'LICENCIATURA EN MUSICA',
#        'INEGINERIA QUIMICA', 'INGENEIRIA MECANICA',
#        'LICENCIATURA EN ESPAÑOL Y LITERATURA',
#        'MICROBIOLOGIA Y BIOANALISIS', 'LICENCIATURA EN MATEMATICAS',
#        'INGENIERIA MECANICA'], dtype=object)

# %% [markdown]
# ## Nivel

# %%
nivel = df['Nivel']
x_values = df['Nivel'].value_counts()
modaNivel = stat.mode(x_values.index)
x_values.sort_index().plot(kind = 'bar', color = ['blue','blue','blue','blue','blue','blue','blue','orange','blue','blue'])
print(modaNivel)
# Out:
# 8

# %% [markdown]
# # Andrea acá el analisis pues con palabras sobre la grafica, lo que se observa y lo que se puede inferir

# %% [markdown]
# ## Carrera

# %%
carrera = df['Carrera']
ccarreras = df['Carrera'].value_counts()
modac = stat.mode(carrera)
plt.pie(ccarreras, labels=ccarreras.index)
plt.show()
plt.close('all')
print('Mayoría de estudiantes que respondieron son del programa de: '+ modac)
# Out:
# Mayoría de estudiantes que respondieron son del programa de: INGENIERIA DE SISTEMAS

# %% [markdown]
# # Analisis de la carrera

# %% [markdown]
# ## Tiempo de uso de la plataforma MOODLE

# %%
df.replace({'Tiempo de uso':{'Sólo al final del curso, para presentar parciales': 'Al final del curso'}}, inplace=True)
y1 = df['Tiempo de uso'].value_counts()
plt.plot(y1,'o')
plt.grid()

# %% [markdown]
# ### decir por qué el uso en su mayoría es de 1-2 horas, es decir, darle sentido a esa respuesta.
# ### una curiosidad de por qué puede ser usada solo al final del curso

# %% [markdown]
# ## Uso para parciales, quices o examenes

# %%
print(df['Frecuencia pruebas'].mean())
# Out:
# 2.727272727272727

# %%
plt.boxplot(df['Frecuencia pruebas'])
plt.show()

# %% [markdown]
# ## hablar de datos atipicos, la media,

# %%
fig, axes = plt.subplots(1, sharex=True, figsize=(10,6)) #2 graficas, compartir el eje x

sns.boxplot(x = df['Frecuencia pruebas'],  orient="h", ax=axes[0])

plt.suptitle("Porcentaje del uso de las aulas virtuales antes y durante la pandemia")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-347-d6256c6d9e06> in <module>
#       1 fig, axes = plt.subplots(1, sharex=True, figsize=(10,6)) #2 graficas, compartir el eje x
#       2
# ----> 3 sns.boxplot(x = df['Frecuencia pruebas'],  orient="h", ax=axes[0])
#       4
#       5 plt.suptitle("Porcentaje del uso de las aulas virtuales antes y durante la pandemia")
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
df['Area mayor utilidad'].unique()
# Out:
# array(['Materias de carrera ( arriba de 5to semestre)',
#        'Materias de ciencias básicas (ciclo básico)', 'Electivas'],
#       dtype=object)

# %%
sns.histplot(data=df, y="Area mayor utilidad", color = 'red')
plt.xlabel('Número de estudiantes')
plt.show()
